# %%
from utils import *

results = extract_power_readings("2026-01-01","2026-08-01")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from utils import *
#       3 results = extract_power_readings("2026-01-01","2026-08-01")
#
# File c:\Users\storr\chargebnb\backend\utils.py:12
#      10 import xml.etree.ElementTree as ET
#      11 from mappings import lookup_area
# ---> 12 from .db import pool
#      13 import asyncio
#      14 from .mqtt_class import MQTTClass
#
# ImportError: attempted relative import with no known parent package
